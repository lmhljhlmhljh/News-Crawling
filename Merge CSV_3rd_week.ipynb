# %%
import pandas as pd
import numpy as np
import nltk, re
import os

# %%
df1 = pd.read_csv('KHerald_business(44985).csv', encoding='utf-8', engine='python')
df2 = pd.read_csv('KHerald_entertainment.csv', encoding='utf-8', engine='python')
df3 = pd.read_csv('KHerald_lifestyle(15600).csv', encoding='utf-8', engine='python')
df4 = pd.read_csv('KHerald_national(40574).csv', encoding='utf-8', engine='python')
df5 = pd.read_csv('KHerald_opinion(16165).csv', encoding='utf-8', engine='python')
df6 = pd.read_csv('KHerald_sports(11132).csv', encoding='utf-8', engine='python')
df7 = pd.read_csv('KHerald_world(21999).csv', encoding='utf-8', engine='python')

# %%
# Dataframe 병합하기
df = pd.concat([df1,df2,df3,df4,df5,df6,df7])
df
# Out:
#                                                 headline  \
# 0      [Management in Korea] Why governance reform is...
# 1                                               headline
# 2      Retail giants eye luxury segment to bolster on...
# 3      [From the Scene] SsangYong’s Changwon plant re...
# 4      Samsung slips 26 notches in global corporate r...
# 5       Eximbank runs soup kitchen during holiday season
# 6      [Herald Interview] Local mindset behind global...
# 7        Coupang publishes ‘Mini business impact report’
# 8      Tokyo willing to discuss export controls with ...
# 9      Rising nickel prices bode well for cathode mat...
# 10     [New Economic Non-order:3] G-7 loses prestige ...
# 11     Naver, Kakao in battle over Korea’s mobile pay...
# 12     S. Korea's pork exports to remain intact despi...
# 13     National Assembly speaker inspects Samsung SDI...
# 14     [News Focus] Korean chipmakers expect to botto...
# ...

# %%
# CSV file로 저장하기
df.to_csv('KH_3rd_week(165682).csv', index=False, encoding= 'utf-8')

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined
