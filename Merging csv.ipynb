# %%
#Import Modules
import pandas as pd
import numpy as np
import nltk, re
import os

# %%
df1 = pd.read_csv('Korean_times_sample(5577).csv', encoding='utf-8', engine='python')
df2 = pd.read_csv('Korean_times_sample_2(7388).csv', encoding='utf-8', engine='python')
df3 = pd.read_csv('Korean_times_sample_2(7388).csv', encoding='utf-8', engine='python')

# %%
df_KT = pd.concat([df1,df2,df3])
df_KT
# Out:
#                                                headline  \
# 0     NK-US nuclear talks will be delayed until end ...
# 1     Moon requests confirmation hearing report for ...
# 2     'CJ Group heir-apparent also had marijuana can...
# 3     Moon presses on with appointment of justice mi...
# 4      Moon's comment on education reform creates stir
# 5     Approaching typhoon Lingling feared to wreak d...
# 6     Will foreign ministry generate outcome this ti...
# 7     Seasonal migrant workers to be allowed to stay...
# 8     Prime Minister meets former Japanese chief cab...
# 9     North Korea tightening strategic alliance with...
# 10    Gov't urged to open more hydrogen fueling stat...
# 11            Lawmakers under fire over sexist remarks
# 12         S. Korea, Myanmar agree to enhance relations
# 13    48 caught this year for trying to avoid milita...
# 14    Ethiopia stresses fast-growing economy at Seou...
# 15    CJ Group heir apparent caught smuggling mariju...
# ...

# %%
df_KT.to_csv('Korea Times(20352개).csv', index=False, encoding= 'utf-8')
